# %% [markdown]
# # DPO

# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'potion.visualization.notebook_utils' from '/home/matteo/policy-optimization/potion/visualization/notebook_utils.py'>

# %% [markdown]
# # Cartpole

# %% [markdown]
# ## Tuning

# %%
os.chdir('/home/matteo/policy-optimization/results/pgpevsrandomist')

# %% [markdown]
# ### Learning std, natural

# %%
nu.compare('contcartpole', 
           ['pgpe_01', 'pgpe_001', 'pgpe_0001'], 
           keys=['Car', 'Perf'],
           conf=0.95,
           rows=100)
# Out:
# pgpe_01: 167.358294 +- 1.329807
# pgpe_001: 82.987858 +- 1.252210
# pgpe_0001: 42.612127 +- 0.044487
# pgpe_01: 191.262060 +- 0.491748
# pgpe_001: 136.090720 +- 1.602293
# pgpe_0001: 43.553140 +- 0.302143
# [<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>]

# %% [markdown]
# ### Fixed std=1, natural

# %%
nu.compare('contcartpole', 
           ['pgpex_1', 'pgpex_01', 'pgpex_001'], 
           keys=['Car', 'Perf'],
           bootstrap=True,
           conf=0.95,
           resamples=10000,
           rows=100)
# Out:
# pgpex_1: 180.166441 +- 1.004138
# pgpex_01: 161.497557 +- 0.776190
# pgpex_001: 70.637472 +- 0.241323
# pgpex_1: 195.320000 +- 0.338634
# pgpex_01: 188.574820 +- 0.426192
# pgpex_001: 115.414260 +- 0.656568
# [<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('contcartpole', 'pgpex_1', 'Car', path='/home/matteo/pomits-conf/data/cartpole200', rows=100, conf=0.95, bootstrap=False)
nu.save_csv('contcartpole', 'pgpex_01', 'Car', path='/home/matteo/pomits-conf/data/cartpole200', rows=100, conf=0.95, bootstrap=False)
nu.save_csv('contcartpole', 'pgpex_001', 'Car', path='/home/matteo/pomits-conf/data/cartpole200', rows=100, conf=0.95, bootstrap=False)

# %% [markdown]
# ### Horizon=500, std=1

# %%
nu.compare('contcartpole', 
           ['pgpel_1', 'pgpel_01', 'pgpel_001'], 
           keys=['Car', 'Perf'],
           bootstrap=True,
           conf=0.95,
           resamples=10000,
           rows=100)
# Out:
# pgpel_1: 298.688924 +- 37.069938
# pgpel_01: 329.374737 +- 2.533077
# pgpel_001: 83.505896 +- 0.520009
# pgpel_1: 358.706540 +- 44.006452
# pgpel_01: 441.054820 +- 3.057696
# pgpel_001: 182.603280 +- 1.811615
# [<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('contcartpole', 'pgpel_1', 'Car', path='/home/matteo/pomits-conf/data/cartpole500', rows=100, conf=0.95, bootstrap=False)
nu.save_csv('contcartpole', 'pgpel_01', 'Car', path='/home/matteo/pomits-conf/data/cartpole500', rows=100, conf=0.95, bootstrap=False)
nu.save_csv('contcartpole', 'pgpel_001', 'Car', path='/home/matteo/pomits-conf/data/cartpole500', rows=100, conf=0.95, bootstrap=False)

# %% [markdown]
# ### Horizon=1000, std=1

# %%
nu.compare('contcartpole', 
           ['pgpell_1', 'pgpell_01', 'pgpell_001'], 
           keys=['Car', 'Perf'],
           bootstrap=True,
           conf=0.95,
           resamples=10000,
           rows=100)
# Out:
# pgpell_1: 404.440473 +- 71.924789
# pgpell_01: 454.059790 +- 22.686590
# pgpell_001: 89.905450 +- 0.764039
# pgpell_1: 533.201460 +- 96.570244
# pgpell_01: 747.072160 +- 26.671806
# pgpell_001: 244.838080 +- 4.019732
# [<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('minigolf', 'dpo', 'perf', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'bdpo', 'perf', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'reinforcep', 'perf', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'reinforcef', 'perf', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)

nu.save_csv('minigolf', 'dpo', 'fail', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'bdpo', 'fail', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'reinforcep', 'fail', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
nu.save_csv('minigolf', 'reinforcef', 'fail', path='/home/matteo/deterministic/data/minigolf016', rows=700, conf=0.95, bootstrap=True, resamples=100000)
