# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %%
os.chdir('/home/matteo/potion/logs')

# %%
nu.compare('gridworld', 
           ['GPOMDP'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# GPOMDP: 1.553483 +- 0.000000
# [<Figure size 432x288 with 1 Axes>]
