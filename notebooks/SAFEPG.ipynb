# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'potion.visualization.notebook_utils' from '/home/matteo/policy-optimization/potion/visualization/notebook_utils.py'>

# %% [markdown]
# # LQG safe

# %% [markdown]
# seeds = [2030, 4473, 5759, 5756, 4146, 1428, 9723, 3212, 8589, 1971]

# %%
os.chdir('/home/matteo/policy-optimization/results/SAFEPG')

# %%
nu.compare('lq', 
           ['spg', 'sspg', 'adabatch'], 
           keys=['Perf'], 
           separate=False,
           xkey='TotSamples',
           conf=.99,
           rows=None)
# Out:
# spg: -6.642081 +- 0.002040
# sspg: -6.294288 +- 0.014491
# adabatch: -6.561430 +- 0.003686
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'spg', 'Perf', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=.95, rows=None)
nu.save_csv('lq', 'sspg', 'Perf', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=.95, rows=None, step=20)
nu.save_csv('lq', 'adabatch', 'Perf', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=.95, rows=None, step=5)
# Out:
# 583
# 476
# 403

# %%
nu.compare('lq', 
           ['spg', 'sspg', 'adabatch'], 
           keys=['BatchSize'], 
           xkey='TotSamples',
           separate=False,
           conf=1,
           rows=None)
# Out:
# spg: 17159.304452 +- 66.335498
# sspg: 1067.040862 +- 157.789531
# adabatch: 4965.527742 +- 22.278724
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'spg', 'BatchSize', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=0.95, rows=None)
nu.save_csv('lq', 'sspg', 'BatchSize', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=0.95, rows=None, step=20)
nu.save_csv('lq', 'adabatch', 'BatchSize', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=0.95, rows=None, step=5)
# Out:
# 583
# 476
# 403

# %%
nu.compare('lq', 
           ['spg', 'sspg', 'adabatch'], 
           keys=['param0'], 
           xkey='TotSamples',
           separate=False,
           conf=1,
           rows=None)
# Out:
# spg: -0.053836 +- 0.000009
# sspg: -0.454321 +- 0.000096
# adabatch: -0.124016 +- 0.000014
# [<Figure size 432x288 with 1 Axes>]
