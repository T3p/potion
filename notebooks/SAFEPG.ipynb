# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'potion.visualization.notebook_utils' from '/home/matteo/policy-optimization/potion/visualization/notebook_utils.py'>

# %% [markdown]
# # LQG safe

# %% [markdown]
# seeds = [2030, 4473, 5759, 5756, 4146, 1428, 9723, 3212, 8589, 1971]

# %%
os.chdir('/home/matteo/policy-optimization/results/SAFEPG')

# %%
nu.compare('lq_lqg', 
           ['spg', 'sspg'], 
           keys=['Perf'], 
           separate=False,
           xkey='TotSamples',
           conf=.99,
           rows=None)
# Out:
# spg: -36.294517 +- 0.133012
# sspg: -28.671158 +- 0.171449
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq_lqg', 'spg', 'Perf', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=.99, rows=None)
nu.save_csv('lq_lqg', 'sspg', 'Perf', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=.99, rows=None)

# %%
nu.compare('lq_lqg', 
           ['spg', 'sspg'], 
           keys=['BatchSize'], 
           xkey='TotSamples',
           separate=False,
           conf=1,
           rows=None)
# Out:
# spg: 1223.659622 +- 20.171815
# sspg: 361.693249 +- 73.171823
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq_lqg', 'spg', 'BatchSize', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=1, rows=None)
nu.save_csv('lq_lqg', 'sspg', 'BatchSize', xkey='TotSamples', path='/home/matteo/phd-thesis/data', conf=1, rows=None)
