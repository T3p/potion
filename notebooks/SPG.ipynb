# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %% [markdown]
# seeds = [7479 8255 4810 8877 2802]

# %% [markdown]
# # LQG

# %%
os.chdir('/home/matteo/potion/results')

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: -6.563589 +- 0.003727
# AdaBatch: -6.650859 +- 0.003346
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 721
# 667

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='Iterations')
# Out:
# SPG: 5402.458449 +- 45.394598
# AdaBatch: 6095.483533 +- 19.932080
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 721
# 667

# %% [markdown]
# # Gridworld

# %%
os.chdir('/home/matteo/potion/results')

# %%
nu.compare('gridworld', 
           ['SPG', 'GPOMDP'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: -0.138320 +- 0.005962
# GPOMDP: 0.115124 +- 0.008462
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('gridworld', 
           ['SPG', 'GPOMDP'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='Iterations')
# Out:
# SPG: 1574.446870 +- 42.007141
# GPOMDP: 100.000000 +- 0.000000
# [<Figure size 432x288 with 1 Axes>]
