# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %% [markdown]
# seeds = [8092,	4462,	8930,	4811,	568]

# %% [markdown]
# # LQG

# %%
os.chdir('/home/matteo/potion/results')

# %%
nu.compare('lq', 
           ['SPG','AdaBatch', 'fSPG'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: -6.393611 +- 0.001619
# AdaBatch: -6.646853 +- 0.002058
# fSPG: -6.339242 +- 0.002305
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 265
# 571

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch', 'fSPG'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 37870.432331 +- 184.470376
# AdaBatch: 17502.493357 +- 37.784107
# fSPG: 21106.084906 +- 312.276676
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 265
# 571

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=50,
           xkey='TotSamples')
# Out:
# SPG: 11303.600000 +- 65.258183
# AdaBatch: 10852.316000 +- 30.015343
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 265
# 571

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch', 'fSPG'], 
           keys=['Oracle'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: -32.839785 +- 0.004592
# AdaBatch: -63.920833 +- 0.003110
# fSPG: -30.818095 +- 0.089017
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'Oracle', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'Oracle', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 265
# 571

# %%
nu.compare('lq', 
           ['AdaBatch'], 
           keys=['StepSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# AdaBatch: 0.000134 +- 0.000001
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['GradNorm'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 0.808760 +- 0.002028
# AdaBatch: 1.267357 +- 0.002741
# [<Figure size 432x288 with 1 Axes>]
