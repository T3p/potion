# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %% [markdown]
# seeds = [8092,	4462,	8930,	4811,	568]

# %%
os.chdir('/home/matteo/potion/results')

# %% [markdown]
# # CARTPOLE

# %%
nu.compare('cartpole', 
           ['SPG', 'GPOMDP'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 9.348049 +- 0.012519
# GPOMDP: 9.793484 +- 0.009451
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('cartpole', 
           ['SPG', 'GPOMDP'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 675.901909 +- 5.822918
# GPOMDP: 100.000000 +- 0.000000
# [<Figure size 432x288 with 1 Axes>]

# %% [markdown]
# # GRIDWORLD

# %%
nu.compare('gridworld', 
           ['EBSPG', 'GPOMDP'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# EBSPG: 0.841339 +- 0.002607
# GPOMDP: 1.742335 +- 0.010475
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 126
# 124

# %%
nu.compare('gridworld', 
           ['EBSPG', 'GPOMDP'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# EBSPG: 13046.567358 +- 37.303566
# GPOMDP: 100.000000 +- 0.000000
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 126
# 124

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['Oracle'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: -36.192753 +- 0.012769
# AdaBatch: -90.818420 +- 0.004320
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['StepSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 0.005000 +- 0.000000
# AdaBatch: 0.000138 +- 0.000001
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('lq', 
           ['SPG', 'AdaBatch'], 
           keys=['GradNorm'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# SPG: 0.619381 +- 0.002329
# AdaBatch: 1.051243 +- 0.002118
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('lq', 'SPG', 'Oracle', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
nu.save_csv('lq', 'AdaBatch', 'Oracle', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None)
# Out:
# 126
# 124

# %% [markdown]
# # Gridworld

# %%
os.chdir('/home/matteo/potion/results')

# %%
nu.compare('gridworld', 
           ['SPG'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# /tmp/ipykernel_20308/3242412258.py in <module>
#       5            conf=.95,
#       6            rows=None,
# ----> 7            xkey='TotSamples')
#
# ~/potion/potion/visualization/notebook_utils.py in compare(env, names, keys, conf, logdir, separate, ymin, ymax, rows, xkey, xmax, bootstrap, resamples, mult, roll)
#     122             mult = [1.] * len(names)
#     123         for i, name in enumerate(names):
# --> 124             dfs = load_all(env + '_' + name, rows=rows)
#     125             dfs = [dfs[j].rolling(roll[i]).mean() for j in range(len(dfs))]
#     126             if separate:
#
# ~/potion/potion/visualization/notebook_utils.py in load_all(name, rows)
#     101
#     102 def load_all(name, rows=200):
# ...

# %%
nu.save_csv('gridworld', 'SPG', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=1)
nu.save_csv('gridworld', 'GPOMDP', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=50)
# Out:
# 2252
# 2000

# %%
nu.compare('gridworld', 
           ['SPG'], 
           keys=['BatchSize', 'GradNorm'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples',
           mult=[1., 2.])
# Out:
# SPG: 4656.580855 +- 187.385243
# SPG: 0.124707 +- 0.001970
# [<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('gridworld', 'SPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=1)
nu.save_csv('gridworld', 'SPG', 'GradNorm', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=1)
# Out:
# 2252
