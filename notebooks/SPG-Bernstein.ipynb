# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %% [markdown]
# seeds = [8092,	4462,	8930,	4811,	568]

# %%
os.chdir('/home/matteo/potion/results')

# %% [markdown]
# # CARTPOLE

# %%
nu.compare('cartpole', 
           ['RSPG', 'GPOMDP', 'RSPG8', 'RSPG1', 'RSPG4'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG: 9.607725 +- 0.011393
# GPOMDP: 9.864387 +- 0.006082
# RSPG8: 9.806052 +- 0.006624
# RSPG1: 9.331556 +- 0.037774
# RSPG4: 9.651428 +- 0.013109
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('cartpole', 
           ['RSPG', 'RSPG8', 'RSPG1', 'RSPG4'], 
           keys=['Target'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG: 8.470501 +- 0.008946
# RSPG8: 2.904331 +- 0.000985
# RSPG1: 8.525949 +- 0.064519
# RSPG4: 6.727140 +- 0.011072
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('cartpole', 
           ['RSPG', 'GPOMDP'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG: 623.135492 +- 4.070865
# GPOMDP: 100.000000 +- 0.000000
# [<Figure size 432x288 with 1 Axes>]
