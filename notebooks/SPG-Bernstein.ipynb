# %%
import os
import matplotlib.pyplot as plt
import potion.visualization.notebook_utils as nu

# %% [markdown]
# seeds = [8092,	4462,	8930,	4811,	568]

# %%
os.chdir('/home/matteo/potion/results')

# %% [markdown]
# # CARTPOLE

# %%
nu.compare('cartpole', 
           ['RSPG', 'GPOMDP', 'RSPG8', 'RSPG1', 'RSPG4'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG: 9.607725 +- 0.011393
# GPOMDP: 9.864387 +- 0.006082
# RSPG8: 9.855196 +- 0.005323
# RSPG1: 9.410190 +- 0.031103
# RSPG4: 9.724141 +- 0.010644
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.compare('cartpole', 
           ['RSPG1'], 
           keys=['Perf'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG1: 9.410190 +- 0.031103
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('cartpole', 'RSPG', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'GPOMDP', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'RSPG1', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'RSPG4', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'RSPG8', 'Perf', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
# Out:
# 334
# 2000
# 137
# 668
# 1842

# %%
nu.compare('cartpole', 
           ['RSPG1'], 
           keys=['Target'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='Iterations')
# Out:
# RSPG1: 8.892956 +- 0.030375
# [<Figure size 432x288 with 1 Axes>]

# %%
#nu.save_csv('cartpole', 'RSPG1', 'Target', xkey='Iterations', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
#nu.save_csv('cartpole', 'RSPG1', 'Perf', xkey='Iterations', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)

# %%
nu.compare('cartpole', 
           ['RSPG1', 'RSPG', 'RSPG4'], 
           keys=['BatchSize'], 
           separate=False,
           conf=.95,
           rows=None,
           xkey='TotSamples')
# Out:
# RSPG1: 1587.873016 +- 27.681925
# RSPG: 623.135492 +- 4.070865
# RSPG4: 300.275697 +- 0.227679
# [<Figure size 432x288 with 1 Axes>]

# %%
nu.save_csv('cartpole', 'RSPG', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'RSPG1', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
nu.save_csv('cartpole', 'RSPG4', 'BatchSize', xkey='TotSamples', path='/home/matteo/potion/reports', conf=.95, rows=None, step=10)
# Out:
# 334
# 137
# 668
